# %% [markdown]
# # Netflix Dataset Visualization
#
# ### Modules Used

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import nan

# %% [markdown]
# ### Dataset

# %%
df = pd.read_csv("netflix_titles.csv")
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ### Handling NAN

# %%
df['country'] = df['country'].fillna(df['country'].mode()[0])
df['cast'].replace(nan, 'No Data',inplace  = True)
df['director'].replace(nan, 'No Data',inplace  = True)

# Drops
df.dropna(inplace=True)

# Drop Duplicates
df.drop_duplicates(inplace= True)
df.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# ### Netflix Content Type

# %%
netflix_colors = ['#E50914', '#000000']
plt.bar(['Movies', 'TV Shows'], [movies, tv], color=netflix_colors)
plt.xlabel('Type')
plt.ylabel('Count')
plt.title('Movies vs TV Shows')
plt.show()

# %% [markdown]
# ### Top 10 countries with netflix content

# %%
country_counts = df.country.value_counts()
countries = country_counts.head(10)
sns.set_style({'axes.facecolor': 'black'})
plt.figure(figsize=(15,8))
colors = ['#FF5733', '#FFC300', '#36A2EB', '#4CAF50', '#FF5733']
plt.bar(countries.index,countries.values,color=colors)
plt.title("Top 10 countries with netflix content")
plt.show()

# %% [markdown]
# ### Content on Netflix with different types of ratings

# %%
rating = df.rating.value_counts().head(10)
plt.figure(figsize=(10,10))
sns.set(style='whitegrid')
colors = ['#E50914', '#B20710', '#221F1F', '#8C8C8C', '#F5F5F1',
          '#D32F2F', '#FF5733', '#FFC300', '#36A2EB', '#4CAF50']
plt.pie(rating.values, labels=[f'{i} = {j}' for i,j in zip(rating.index,rating.values)], colors=colors)
plt.title("rating types")
plt.show()
